# %%
from pydub import AudioSegment

path="C:/Users/acer/Pictures/jurnal/audio/"
audio=AudioSegment.from_mp3(path+"sound-campursari.mp3")
n=len(audio)
counter=1
interval=5*1000
overlap=0.0*1000
start=0
end=0
flag=0
for i in range(0,n,interval):
    if i == 0:
        start = 0
        end=interval
    else:
        start=end-overlap 
        end=start+interval
    chunk=audio[start:end]
    filename=path+'potongan_campursari/pot'+str(counter)+'.wav'
    chunk.export(filename,format="wav")
    print(str(counter)+". Start = "+str(start/1000)+" \
        Detik end = "+str(end/1000) + " Detik")
    counter = counter + 1
# Out:
# 1. Start = 0.0         Detik end = 5.0 Detik
# 2. Start = 5.0         Detik end = 10.0 Detik
# 3. Start = 10.0         Detik end = 15.0 Detik
# 4. Start = 15.0         Detik end = 20.0 Detik
# 5. Start = 20.0         Detik end = 25.0 Detik
# 6. Start = 25.0         Detik end = 30.0 Detik
# 7. Start = 30.0         Detik end = 35.0 Detik
# 8. Start = 35.0         Detik end = 40.0 Detik
# 9. Start = 40.0         Detik end = 45.0 Detik
# 10. Start = 45.0         Detik end = 50.0 Detik
# 11. Start = 50.0         Detik end = 55.0 Detik
# 12. Start = 55.0         Detik end = 60.0 Detik
# 13. Start = 60.0         Detik end = 65.0 Detik
# 14. Start = 65.0         Detik end = 70.0 Detik
# 15. Start = 70.0         Detik end = 75.0 Detik
# 16. Start = 75.0         Detik end = 80.0 Detik
# 17. Start = 80.0         Detik end = 85.0 Detik
# 18. Start = 85.0         Detik end = 90.0 Detik
# 19. Start = 90.0         Detik end = 95.0 Detik
# 20. Start = 95.0         Detik end = 100.0 Detik
# ...

# %%
from pydub import AudioSegment

path="C:/Users/acer/Pictures/jurnal/audio/"
audio=AudioSegment.from_mp3(path+"sound-keroncong.mp3")
n=len(audio)
counter=1
interval=5*1000
overlap=0.0*1000
start=0
end=0
flag=0
for i in range(0,n,interval):
    if i == 0:
        start = 0
        end=interval
    else:
        start=end-overlap
        end=start+interval
    chunk=audio[start:end]
    filename=path+'potongan_keroncong/pot'+str(counter)+'.wav'
    chunk.export(filename,format="wav")
    print(str(counter)+". Start = "+str(start/1000)+" \
        Detik end = "+str(end/1000) + " Detik")
    counter = counter + 1
# Out:
# 1. Start = 0.0         Detik end = 5.0 Detik
# 2. Start = 5.0         Detik end = 10.0 Detik
# 3. Start = 10.0         Detik end = 15.0 Detik
# 4. Start = 15.0         Detik end = 20.0 Detik
# 5. Start = 20.0         Detik end = 25.0 Detik
# 6. Start = 25.0         Detik end = 30.0 Detik
# 7. Start = 30.0         Detik end = 35.0 Detik
# 8. Start = 35.0         Detik end = 40.0 Detik
# 9. Start = 40.0         Detik end = 45.0 Detik
# 10. Start = 45.0         Detik end = 50.0 Detik
# 11. Start = 50.0         Detik end = 55.0 Detik
# 12. Start = 55.0         Detik end = 60.0 Detik
# 13. Start = 60.0         Detik end = 65.0 Detik
# 14. Start = 65.0         Detik end = 70.0 Detik
# 15. Start = 70.0         Detik end = 75.0 Detik
# 16. Start = 75.0         Detik end = 80.0 Detik
# 17. Start = 80.0         Detik end = 85.0 Detik
# 18. Start = 85.0         Detik end = 90.0 Detik
# 19. Start = 90.0         Detik end = 95.0 Detik
# 20. Start = 95.0         Detik end = 100.0 Detik
# ...

# %%
from pydub import AudioSegment

path="C:/Users/acer/Pictures/jurnal/audio/"
audio=AudioSegment.from_mp3(path+"sound-dangdut.mp3")
n=len(audio)
counter=1
interval=5*1000
overlap=0.0*1000
start=0
end=0
flag=0
for i in range(0,n,interval):
    if i == 0:
        start = 0
        end=interval
    else:
        start=end-overlap
        end=start+interval
    chunk=audio[start:end]
    filename=path+'potongan_dangdut/pot'+str(counter)+'.wav'
    chunk.export(filename,format="wav")
    print(str(counter)+". Start = "+str(start/1000)+" \
        Detik end = "+str(end/1000) + " Detik")
    counter = counter + 1
# Out:
# 1. Start = 0.0         Detik end = 5.0 Detik
# 2. Start = 5.0         Detik end = 10.0 Detik
# 3. Start = 10.0         Detik end = 15.0 Detik
# 4. Start = 15.0         Detik end = 20.0 Detik
# 5. Start = 20.0         Detik end = 25.0 Detik
# 6. Start = 25.0         Detik end = 30.0 Detik
# 7. Start = 30.0         Detik end = 35.0 Detik
# 8. Start = 35.0         Detik end = 40.0 Detik
# 9. Start = 40.0         Detik end = 45.0 Detik
# 10. Start = 45.0         Detik end = 50.0 Detik
# 11. Start = 50.0         Detik end = 55.0 Detik
# 12. Start = 55.0         Detik end = 60.0 Detik
# 13. Start = 60.0         Detik end = 65.0 Detik
# 14. Start = 65.0         Detik end = 70.0 Detik
# 15. Start = 70.0         Detik end = 75.0 Detik
# 16. Start = 75.0         Detik end = 80.0 Detik
# 17. Start = 80.0         Detik end = 85.0 Detik
# 18. Start = 85.0         Detik end = 90.0 Detik
# 19. Start = 90.0         Detik end = 95.0 Detik
# 20. Start = 95.0         Detik end = 100.0 Detik
# ...
